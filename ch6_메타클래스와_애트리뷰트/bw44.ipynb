# %%
class Resistor:
    def __init__(self, ohms):
        self.ohms = ohms
        self.voltage = 0
        self.current = 0

r1 = Resistor(50e3)
r1.ohms = 10e3

r1.ohms += 5e3

#
class VoltageResistance(Resistor):
    def __init__(self, ohms):
        super().__init__(ohms)
        self._voltage = 0

    @property
    def voltage(self):
        return self._voltage

    @voltage.setter
    def voltage(self, voltage):
        self._voltage = voltage
        self.current = self._voltage / self.ohms

r2 = VoltageResistance(1e3)
print(f'이전: {r2.current:.2f} 암페어')
r2.voltage = 10
print(f'이후: {r2.current:.2f} 암페어')
# Out:
# 이전: 0.00 암페어
# 이후: 0.01 암페어

# %%
#
class BoundedResistance(Resistor):
    def __init__(self, ohms):
        super().__init__(ohms)

    @property
    def ohms(self):
        return self._ohms

    @ohms.setter
    def ohms(self, ohms):
        if ohms <= 0:
            raise ValueError(f'저항 > 0이어야 합니다. 실제 값: {ohms}')
        self._ohms = ohms
""
# Out:
# ''

# %%
r3 = BoundedResistance(1e3)
r3.ohms = 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-09ad73b9a022> in <module>
#       1 r3 = BoundedResistance(1e3)
# ----> 2 r3.ohms = 0
#
# <ipython-input-12-84330724cf9b> in ohms(self, ohms)
#      11     def ohms(self, ohms):
#      12         if ohms <= 0:
# ---> 13             raise ValueError(f'저항 > 0이어야 합니다. 실제 값: {ohms}')
#      14         self._ohms = ohms
#      15 ""
#
# ValueError: 저항 > 0이어야 합니다. 실제 값: 0

# %%
r3 = BoundedResistance(-5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-5973abc3cced> in <module>
# ----> 1 r3 = BoundedResistance(-5)
#
# <ipython-input-12-84330724cf9b> in __init__(self, ohms)
#       2 class BoundedResistance(Resistor):
#       3     def __init__(self, ohms):
# ----> 4         super().__init__(ohms)
#       5
#       6     @property
#
# <ipython-input-8-44b1b724328f> in __init__(self, ohms)
#       1 class Resistor:
#       2     def __init__(self, ohms):
# ----> 3         self.ohms = ohms
#       4         self.voltage = 0
#       5         self.current = 0
#
# <ipython-input-12-84330724cf9b> in ohms(self, ohms)
#      11     def ohms(self, ohms):
#      12         if ohms <= 0:
# ---> 13             raise ValueError(f'저항 > 0이어야 합니다. 실제 값: {ohms}')
#      14         self._ohms = ohms
#      15 ""
#
# ValueError: 저항 > 0이어야 합니다. 실제 값: -5

# %%
#
class Resistor:
    def __init__(self, ohms):
        self.ohms = ohms
        self.voltage = 0
        self.current = 0
        
#
class FixedResistance(Resistor):
    def __init__(self, ohms):
        super().__init__(ohms)

    @property
    def ohms(self):
        return self._ohms

    @ohms.setter
    def ohms(self, ohms):
        print('hasattr 여부 : ', hasattr(self, 'ohms'))
        if hasattr(self, '_ohms'):
            raise AttributeError("Ohms는 불변객체입니다")
        self._ohms = ohms

# %%
r4 = FixedResistance(1e3)
# 오류가 나는 부분. 오류를 보고 싶으면 커멘트를 해제할것
#r4.ohms = 2e3
# Out:
# hasattr 여부 :  False

# %%
r4.ohms = 2e3
# Out:
# hasattr 여부 :  True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-9addc5737525> in <module>
# ----> 1 r4.ohms = 2e3
#
# <ipython-input-26-7f57b15f3895> in ohms(self, ohms)
#      19         print('hasattr 여부 : ', hasattr(self, 'ohms'))
#      20         if hasattr(self, '_ohms'):
# ---> 21             raise AttributeError("Ohms는 불변객체입니다")
#      22         self._ohms = ohms
#
# AttributeError: Ohms는 불변객체입니다

# %%
# self.a 와 self._a가 둘다 있는건지 테스트
# 프로퍼티를 바르게 사용하는 방법 제대로 알기

class Test():
    def __init__(self, a):
        print('a 생성 전')
        self.a = a
        print('a 생성 후')
        print(self.a)
        print(self._a)


    @property
    def a(self):
        return self._a
    
    @a.setter
    def a(self, a):
        print('a 생성 전 1')
        self._a = a
        print('a 생성 전 2')
        print(self.a)
        print(self._a)

# %%
t = Test('test')
# Out:
# a 생성 전
# a 생성 전 1
# a 생성 전 2
# a 생성 후
# test
# test

# %%
t.a
# Out:
# 'test'

# %%
t._a
# Out:
# 'test'

# %%
t.__dict__
# Out:
# {'_a': 'test'}

# %%
Test.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__init__': <function __main__.Test.__init__(self, a)>,
#               'a': <property at 0x20e41ece7c0>,
#               '__dict__': <attribute '__dict__' of 'Test' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Test' objects>,
#               '__doc__': None})

# %%
class Resistor:
    def __init__(self, ohms):
        self.ohms = ohms
        self.voltage = 0
        self.current = 0

#
class MysteriousResistor(Resistor):
    @property
    def ohms(self):
        self.voltage = self._ohms * self.current
        return self._ohms

    @ohms.setter
    def ohms(self, ohms):
        self._ohms = ohms

r7 = MysteriousResistor(10)
r7.current = 0.01
print(f'이전: {r7.voltage:.2f}')
r7.ohms
print(f'이후: {r7.voltage:.2f}')
# Out:
# 이전: 0.00
# 이후: 0.10

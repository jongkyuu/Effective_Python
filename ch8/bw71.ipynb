# %%
import random

# walus 연산자 때문에 파이썬 3.8이상에서만 실행됨

class Email:
    def __init__(self, sender, receiver, message):
        self.sender = sender
        self.receiver = receiver
        self.message = message

    def __str__(self):
        return f"Email({self.sender},{self.receiver},{self.message})"

class NoEmailError(Exception):
    pass

def try_receive_email():
    # Email 인스턴스를 하나 반환한거나, NoEmailError를 발생시킨다
    # 99%확률로 Email을 발생시킴
    if (i := random.randint(0,100)) > 99:
        raise NoEmailError
    else:
        return Email(f'Sender{i}','Receiver','Message!')

def produce_emails(queue):
    while True:
        try:
            email = try_receive_email()
        except NoEmailError:
            return
        else:
            queue.append(email)  # 생산자

def consume_one_email(queue):
    if not queue:
        return
    email = queue.pop(0) # 소비자
    print(f"read email: {email}")


def loop(queue, keep_running):
    while keep_running():
        produce_emails(queue)
        consume_one_email(queue)


# 99%확률로 True를 반환
def my_end_func():
    return random.randint(0, 100) > 1


loop([], my_end_func)
# Out:
# read email: Email(Sender5,Receiver,Message!)
# read email: Email(Sender34,Receiver,Message!)
# read email: Email(Sender17,Receiver,Message!)
# read email: Email(Sender98,Receiver,Message!)
# read email: Email(Sender23,Receiver,Message!)
# read email: Email(Sender27,Receiver,Message!)
# read email: Email(Sender66,Receiver,Message!)
# read email: Email(Sender53,Receiver,Message!)
# read email: Email(Sender39,Receiver,Message!)
# read email: Email(Sender61,Receiver,Message!)
# read email: Email(Sender13,Receiver,Message!)
# read email: Email(Sender84,Receiver,Message!)
# read email: Email(Sender60,Receiver,Message!)
# read email: Email(Sender27,Receiver,Message!)
# read email: Email(Sender77,Receiver,Message!)
# read email: Email(Sender51,Receiver,Message!)
# read email: Email(Sender57,Receiver,Message!)
# read email: Email(Sender92,Receiver,Message!)
# read email: Email(Sender10,Receiver,Message!)
# read email: Email(Sender68,Receiver,Message!)
# read email: Email(Sender62,Receiver,Message!)
# read email: Email(Sender2,Receiver,Message!)
# read email: Email(Sender77,Receiver,Message!)
# read email: Email(Sender65,Receiver,Message!)
# read email: Email(Sender96,Receiver,Message!)
# read email: Email(Sender9,Receiver,Message!)
# read email: Email(Sender42,Receiver,Message!)
# read email: Email(Sender16,Receiver,Message!)
# read email: Email(Sender35,Receiver,Message!)
# read email: Email(Sender70,Receiver,Message!)
# read email: Email(Sender19,Receiver,Message!)
# read email: Email(Sender23,Receiver,Message!)
# read email: Email(Sender30,Receiver,Message!)
# read email: Email(Sender38,Receiver,Message!)
# read email: Email(Sender42,Receiver,Message!)
# read email: Email(Sender52,Receiver,Message!)
# read email: Email(Sender49,Receiver,Message!)
# read email: Email(Sender69,Receiver,Message!)
# read email: Email(Sender41,Receiver,Message!)
# read email: Email(Sender79,Receiver,Message!)
# read email: Email(Sender22,Receiver,Message!)
# read email: Email(Sender22,Receiver,Message!)
# read email: Email(Sender83,Receiver,Message!)
# read email: Email(Sender89,Receiver,Message!)
# read email: Email(Sender42,Receiver,Message!)
# read email: Email(Sender44,Receiver,Message!)
# read email: Email(Sender28,Receiver,Message!)
# read email: Email(Sender14,Receiver,Message!)
# read email: Email(Sender99,Receiver,Message!)
# read email: Email(Sender86,Receiver,Message!)
# read email: Email(Sender48,Receiver,Message!)
# read email: Email(Sender16,Receiver,Message!)
# read email: Email(Sender44,Receiver,Message!)
# read email: Email(Sender23,Receiver,Message!)
# read email: Email(Sender58,Receiver,Message!)
# read email: Email(Sender17,Receiver,Message!)
# read email: Email(Sender54,Receiver,Message!)
# read email: Email(Sender11,Receiver,Message!)
# read email: Email(Sender95,Receiver,Message!)
# read email: Email(Sender53,Receiver,Message!)
# read email: Email(Sender70,Receiver,Message!)
# read email: Email(Sender69,Receiver,Message!)
# read email: Email(Sender17,Receiver,Message!)
# read email: Email(Sender47,Receiver,Message!)
# read email: Email(Sender38,Receiver,Message!)
# read email: Email(Sender44,Receiver,Message!)
# read email: Email(Sender63,Receiver,Message!)
# read email: Email(Sender65,Receiver,Message!)
# read email: Email(Sender70,Receiver,Message!)
# read email: Email(Sender82,Receiver,Message!)
# read email: Email(Sender2,Receiver,Message!)
# read email: Email(Sender71,Receiver,Message!)
# read email: Email(Sender86,Receiver,Message!)
# read email: Email(Sender11,Receiver,Message!)
# read email: Email(Sender97,Receiver,Message!)
# read email: Email(Sender11,Receiver,Message!)
# read email: Email(Sender81,Receiver,Message!)
# read email: Email(Sender90,Receiver,Message!)
# read email: Email(Sender3,Receiver,Message!)
# read email: Email(Sender58,Receiver,Message!)
# read email: Email(Sender46,Receiver,Message!)
# read email: Email(Sender98,Receiver,Message!)
# read email: Email(Sender75,Receiver,Message!)
# read email: Email(Sender91,Receiver,Message!)
# read email: Email(Sender27,Receiver,Message!)
# read email: Email(Sender83,Receiver,Message!)
# read email: Email(Sender80,Receiver,Message!)
# read email: Email(Sender56,Receiver,Message!)
# read email: Email(Sender62,Receiver,Message!)
# read email: Email(Sender31,Receiver,Message!)
# read email: Email(Sender91,Receiver,Message!)
# read email: Email(Sender55,Receiver,Message!)
# read email: Email(Sender56,Receiver,Message!)
# read email: Email(Sender36,Receiver,Message!)
# read email: Email(Sender59,Receiver,Message!)
# read email: Email(Sender38,Receiver,Message!)
# read email: Email(Sender94,Receiver,Message!)
# read email: Email(Sender8,Receiver,Message!)
# read email: Email(Sender73,Receiver,Message!)
# read email: Email(Sender75,Receiver,Message!)
# read email: Email(Sender59,Receiver,Message!)
# read email: Email(Sender76,Receiver,Message!)
# read email: Email(Sender86,Receiver,Message!)
# read email: Email(Sender1,Receiver,Message!)
# read email: Email(Sender60,Receiver,Message!)
# read email: Email(Sender55,Receiver,Message!)
# read email: Email(Sender46,Receiver,Message!)
# read email: Email(Sender14,Receiver,Message!)
# read email: Email(Sender68,Receiver,Message!)
# read email: Email(Sender35,Receiver,Message!)
# read email: Email(Sender42,Receiver,Message!)
# read email: Email(Sender95,Receiver,Message!)
# read email: Email(Sender3,Receiver,Message!)
# read email: Email(Sender84,Receiver,Message!)
# read email: Email(Sender90,Receiver,Message!)
# read email: Email(Sender26,Receiver,Message!)
# read email: Email(Sender64,Receiver,Message!)
# read email: Email(Sender73,Receiver,Message!)
# read email: Email(Sender77,Receiver,Message!)
# read email: Email(Sender89,Receiver,Message!)
# read email: Email(Sender74,Receiver,Message!)
# read email: Email(Sender75,Receiver,Message!)
# read email: Email(Sender92,Receiver,Message!)
# read email: Email(Sender47,Receiver,Message!)
# read email: Email(Sender7,Receiver,Message!)
# read email: Email(Sender17,Receiver,Message!)
# read email: Email(Sender61,Receiver,Message!)
# read email: Email(Sender73,Receiver,Message!)
# read email: Email(Sender29,Receiver,Message!)
# read email: Email(Sender35,Receiver,Message!)
# read email: Email(Sender62,Receiver,Message!)
# read email: Email(Sender26,Receiver,Message!)
# read email: Email(Sender65,Receiver,Message!)
# read email: Email(Sender70,Receiver,Message!)
# read email: Email(Sender47,Receiver,Message!)
# read email: Email(Sender66,Receiver,Message!)
# read email: Email(Sender35,Receiver,Message!)
# read email: Email(Sender60,Receiver,Message!)
# read email: Email(Sender30,Receiver,Message!)
# read email: Email(Sender89,Receiver,Message!)
# read email: Email(Sender66,Receiver,Message!)
# read email: Email(Sender12,Receiver,Message!)
# read email: Email(Sender73,Receiver,Message!)
# read email: Email(Sender47,Receiver,Message!)
# read email: Email(Sender8,Receiver,Message!)
# read email: Email(Sender38,Receiver,Message!)
# read email: Email(Sender60,Receiver,Message!)
# read email: Email(Sender26,Receiver,Message!)
# read email: Email(Sender65,Receiver,Message!)
# read email: Email(Sender56,Receiver,Message!)
# read email: Email(Sender12,Receiver,Message!)
# read email: Email(Sender1,Receiver,Message!)
# read email: Email(Sender38,Receiver,Message!)
# read email: Email(Sender47,Receiver,Message!)
# read email: Email(Sender34,Receiver,Message!)
# read email: Email(Sender83,Receiver,Message!)
# read email: Email(Sender54,Receiver,Message!)
# read email: Email(Sender36,Receiver,Message!)
# read email: Email(Sender91,Receiver,Message!)
# read email: Email(Sender5,Receiver,Message!)
# read email: Email(Sender84,Receiver,Message!)
# read email: Email(Sender0,Receiver,Message!)
# read email: Email(Sender90,Receiver,Message!)
# read email: Email(Sender83,Receiver,Message!)
# read email: Email(Sender30,Receiver,Message!)
# read email: Email(Sender29,Receiver,Message!)
# read email: Email(Sender23,Receiver,Message!)
# read email: Email(Sender60,Receiver,Message!)
# read email: Email(Sender48,Receiver,Message!)
# read email: Email(Sender88,Receiver,Message!)
# read email: Email(Sender22,Receiver,Message!)
# read email: Email(Sender3,Receiver,Message!)
# read email: Email(Sender23,Receiver,Message!)
# read email: Email(Sender61,Receiver,Message!)
# read email: Email(Sender97,Receiver,Message!)
# read email: Email(Sender93,Receiver,Message!)
# read email: Email(Sender75,Receiver,Message!)
# read email: Email(Sender68,Receiver,Message!)
# read email: Email(Sender77,Receiver,Message!)
# read email: Email(Sender88,Receiver,Message!)
# read email: Email(Sender33,Receiver,Message!)
# read email: Email(Sender88,Receiver,Message!)
# read email: Email(Sender74,Receiver,Message!)
# read email: Email(Sender86,Receiver,Message!)
# read email: Email(Sender41,Receiver,Message!)
# read email: Email(Sender79,Receiver,Message!)
# read email: Email(Sender56,Receiver,Message!)
# read email: Email(Sender88,Receiver,Message!)
# read email: Email(Sender25,Receiver,Message!)
# read email: Email(Sender96,Receiver,Message!)
# read email: Email(Sender37,Receiver,Message!)
# read email: Email(Sender84,Receiver,Message!)
# read email: Email(Sender3,Receiver,Message!)
# read email: Email(Sender54,Receiver,Message!)
# read email: Email(Sender94,Receiver,Message!)
# read email: Email(Sender73,Receiver,Message!)
# read email: Email(Sender63,Receiver,Message!)
# read email: Email(Sender55,Receiver,Message!)
# read email: Email(Sender78,Receiver,Message!)
# read email: Email(Sender32,Receiver,Message!)
# read email: Email(Sender0,Receiver,Message!)
# read email: Email(Sender25,Receiver,Message!)
# read email: Email(Sender59,Receiver,Message!)
# read email: Email(Sender55,Receiver,Message!)
# read email: Email(Sender27,Receiver,Message!)
